# %%
import json
import re

from datasets import Dataset, load_dataset
import pandas as pd

dataset = load_dataset("nlpHakdang/beneficiary", data_files = "dart_ver1_1.csv", use_auth_token= "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")
df = pd.DataFrame(dataset['train'])
df_context_mod = df['clean']
# Out:
# Using custom data configuration nlpHakdang___beneficiary-1d32d2b062b3ea54
# Reusing dataset csv (/opt/ml/.cache/huggingface/datasets/csv/nlpHakdang___beneficiary-1d32d2b062b3ea54/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_I1, df_I2, df_II1, df_II2, df_II6 = [], [], [], [], []
for i in range(len(df_context_mod)):
    df_I1.append(eval(df_context_mod[i])['I. 회사의 개요']['1. 회사의 개요'])
    df_I2.append(eval(df_context_mod[i])['I. 회사의 개요']['2. 회사의 연혁'])
    df_II1.append(eval(df_context_mod[i])['II. 사업의 내용']['1. 사업의 개요'])
    df_II2.append(eval(df_context_mod[i])['II. 사업의 내용']['2. 주요 제품 및 서비스'])
    df_II6.append(eval(df_context_mod[i])['II. 사업의 내용']['6. 주요계약 및 연구개발활동'])

contexts = {'회사의 개요' : df_I1, '회사의 연혁' : df_I2, '사업의 개요' : df_II1,'주요 제품 및 서비스' : df_II2, '주요계약 및 연구개발활동' : df_II6}

df_plus = pd.DataFrame(contexts)
df_plus
# Out:
#                                                  회사의 개요  \
# 0     1. 회사의 개요1. 연결대상 종속회사 개황(연결재무제표를 작성하는 주권상장법인이 ...
# 1     1. 회사의 개요 가. 연결대상 종속회사 개황 (1) 연결대상 종속회사 현황(요약)...
# 2     1. 회사의 개요1. 연결대상 종속회사 개황(연결재무제표를 작성하는 주권상장법인이 ...
# 3     1. 회사의 개요1. 연결대상 종속회사 개황(연결재무제표를 작성하는 주권상장법인이 ...
# 4     1. 회사의 개요 (1) 연결대상 종속회사 개황연결대상 종속회사 현황(요약) (단위...
# ...                                                 ...
# 2313  1. 회사의 개요 ※ 한화플러스제1호기업인수목적 주식회사는 주식회사 세림비앤지와 2...
# 2314  1. 회사의 개요 제이씨케미칼(주)의 보고서 제출 기준일 현재 연결대상 종속회사는 ...
# 2315  1. 회사의 개요가. 연결대상 종속회사 개황 (단위 : 사)  구분  연결대상회사수...
# 2316  1. 회사의 개요가. 회사의 법적ㆍ상업적 명칭 당사의 명칭은 "대성산업 주식회사"라...
# 2317  1. 회사의 개요주식회사 자이언트스텝(또는 이하 "연결회사", "연결실체", "회사...
#
#                                                  회사의 연혁  \
# 0     2. 회사의 연혁가. 엑세스바이오 일자  내용  2002년 09월  회사설립  회사...
# 1     2. 회사의 연혁【(주)지오엠씨 주요 연혁】 2016. 12  벤처기업 인증 획득 ...
# 2     2. 회사의 연혁경영진의 중요한 변동 변동일자  주총종류  선임  임기만료 또는해임...
# 3     2. 회사의 연혁-. 글로벌에스엠테크리미티드 항목  일자  내용  비고  (1)  ...
# ...

# %%
result = pd.concat([df, df_plus], axis=1)
del result['clean']
del result['Unnamed: 0']
del result['Unnamed: 0.1']
result
# df.to_csv("dart_v1_2.csv")
# Out:
#       stock_code      report_idx  corp_code   corp_name  report_date  \
# 0         950130  20211115000151     956028      엑세스바이오     20170630
# 1          33030  20211115002044     232317        지오엠씨     20170630
# 2          67130  20211112000043     419989         클루넷     20170630
# 3         900070  20211125000049     783246      글로벌에스엠     20170703
# 4         900120  20211028000448     800084      씨케이에이치     20170703
# ...          ...             ...        ...         ...          ...
# 2313      340440  20211115000416    1416572  한화플러스제1호스팩     20211125
# 2314      137950  20211111000044     664853      제이씨케미칼     20211126
# 2315        9540  20211115001694     164830      한국조선해양     20211022
# 2316      128820  20211115000893     828789        대성산업     20211111
# 2317      289220  20211110000405    1264438      자이언트스텝     20211028
#
#                                                  회사의 개요  \
# 0     1. 회사의 개요1. 연결대상 종속회사 개황(연결재무제표를 작성하는 주권상장법인이 ...
# ...

# %%
# 클루넷이 쏘아올린 큰 공
# http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201 기반으로 kospi, kosdaq, konex 데이터 get
my_corp = result['corp_name'].tolist()
kosdaq = pd.read_csv('kosdaq.csv', encoding='cp949')
kospi = pd.read_csv('kospi.csv', encoding='cp949')
konex = pd.read_csv('konex.csv', encoding='cp949')
kosdaq = kosdaq['종목명'].to_list()
kospi = kospi['종목명'].to_list()
konex = konex['종목명'].to_list()
print(len(kospi))
print(len(kosdaq))
print(len(konex))
# Out:
# 942
# 1531
# 132

# %%
from collections import defaultdict
A = defaultdict(int)
B = []
for i in my_corp:
    if i in kospi:
        A['kospi'] += 1
    elif i in kosdaq:
        A['kosdaq'] += 1
    elif i in konex:
        A['konex'] += 1
    else:
        B.append(i)

print(A['kospi'])
print(A['kosdaq'])
print(A['konex'])

# Kospi, Kosdaq, Konex 어디에도 들어가지 않는 것들
print(B)
# Out:
# 698
# 1459
# 6
# ...

# %%
for i in range(len(B)):
    idx = result[result['corp_name'] == B[i]].index
    result.drop(idx, inplace=True)

# %%
result = result.reset_index()
del result['index']

# %%
result
# Out:
#       stock_code      report_idx  corp_code   corp_name  report_date  \
# 0         950130  20211115000151     956028      엑세스바이오     20170630
# 1         900070  20211125000049     783246      글로벌에스엠     20170703
# 2         900120  20211028000448     800084      씨케이에이치     20170703
# 3         900290  20211028000456    1170962         GRT     20181122
# 4         900340  20210830000685    1328639        윙입푸드     20181130
# ...          ...             ...        ...         ...          ...
# 2158      340440  20211115000416    1416572  한화플러스제1호스팩     20211125
# 2159      137950  20211111000044     664853      제이씨케미칼     20211126
# 2160        9540  20211115001694     164830      한국조선해양     20211022
# 2161      128820  20211115000893     828789        대성산업     20211111
# 2162      289220  20211110000405    1264438      자이언트스텝     20211028
#
#                                                  회사의 개요  \
# 0     1. 회사의 개요1. 연결대상 종속회사 개황(연결재무제표를 작성하는 주권상장법인이 ...
# ...

# %% [markdown]
# # 추가해야할 부분 :
# # 1. 기존에 있던 기업 중에서 기업명 조금 달랐던 것
# # 2. 기존에도 없는 kospi, kosdaq 기업 (konex는 할 필요 없을 것 같기도 - 이건 정해지면 정리하면 좋을듯)ㅇ
