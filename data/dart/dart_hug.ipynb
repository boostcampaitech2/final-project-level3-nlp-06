# %%
from datasets import load_dataset
import pandas as pd

# %%
dataset = load_dataset("nlpHakdang/beneficiary", data_files = "dart_v1_1_remove_context.csv", use_auth_token= "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")
dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_14108/1479889256.py in <module>
# ----> 1 dataset = load_dataset("nlpHakdang/beneficiary", data_files = "dart_v1_1_remove_context.csv.csv", use_auth_token= "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")
#       2 dataset
#
# /opt/conda/envs/lightweight/lib/python3.7/site-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, script_version, **config_kwargs)
#    1636         revision=revision,
#    1637         use_auth_token=use_auth_token,
# -> 1638         **config_kwargs,
#    1639     )
#    1640
#
# ...

# %%
df = pd.DataFrame(dataset['train'])
df
# Out:
#       Unnamed: 0  stock_code      report_idx  corp_code       corp_name  \
# 0              0      950130  20211115000151     956028          엑세스바이오
# 1              1       33030  20211115002044     232317            지오엠씨
# 2              2       67130  20211112000043     419989             클루넷
# 3              3      139200  20211115002442     855145  하이골드오션2호선박투자회사
# 4              4      900070  20211125000049     783246          글로벌에스엠
# ...          ...         ...             ...        ...             ...
# 2594        2594      340440  20211115000416    1416572      한화플러스제1호스팩
# 2595        2595      137950  20211111000044     664853          제이씨케미칼
# 2596        2596        9540  20211115001694     164830          한국조선해양
# 2597        2597      128820  20211115000893     828789            대성산업
# 2598        2598      289220  20211110000405    1264438          자이언트스텝
#
#       report_date                                              clean
# ...

# %%
df.isna().value_counts()
# Out:
# Unnamed: 0  stock_code  report_idx  corp_code  corp_name  report_date  clean
# False       False       False       False      False      False        False    2595
#                                                                        True        4
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#       Unnamed: 0  stock_code      report_idx  corp_code       corp_name  \
# 0              0      950130  20211115000151     956028          엑세스바이오
# 1              1       33030  20211115002044     232317            지오엠씨
# 2              2       67130  20211112000043     419989             클루넷
# 3              3      139200  20211115002442     855145  하이골드오션2호선박투자회사
# 4              4      900070  20211125000049     783246          글로벌에스엠
# ...          ...         ...             ...        ...             ...
# 2594        2594      340440  20211115000416    1416572      한화플러스제1호스팩
# 2595        2595      137950  20211111000044     664853          제이씨케미칼
# 2596        2596        9540  20211115001694     164830          한국조선해양
# 2597        2597      128820  20211115000893     828789            대성산업
# 2598        2598      289220  20211110000405    1264438          자이언트스텝
#
#       report_date                                              clean
# ...

# %%
df.clean = df.clean.map(eval) # change type str to dict. may takes 30 secs for 2500 corps
# Out:
# /opt/conda/envs/lightweight/lib/python3.7/site-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# dict type check
for idx in df.clean.index:
    assert dict == type( df.clean[idx] ), f"eval not work for {idx}."

# %%
df.clean
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14108/3912220875.py in <module>
# ----> 1 df.clean
#
# NameError: name 'df' is not defined
