# %% [markdown]
# ## 1. Load AI Hub news datasets

# %%
import datasets
dataset = datasets.load_dataset('nlpHakdang/aihub-news30k',  data_files={"train":"news_train_1_0.csv", "valid":"news_valid_1_0.csv"}, use_auth_token='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')
# Out:
# Using custom data configuration nlpHakdang___aihub-news30k-0200ce9f9accd6dc
# Reusing dataset csv (/opt/ml/.cache/huggingface/datasets/csv/nlpHakdang___aihub-news30k-0200ce9f9accd6dc/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'category', 'media_sub_type', 'media_name', 'char_count', 'publish_date', 'title', 'original', 'article', 'extractive', 'abstractive'],
#         num_rows: 271093
#     })
#     valid: Dataset({
#         features: ['id', 'category', 'media_sub_type', 'media_name', 'char_count', 'publish_date', 'title', 'original', 'article', 'extractive', 'abstractive'],
#         num_rows: 30122
#     })
# })

# %% [markdown]
# # 2. Visualize

# %% [markdown]
# ## 2.1. train dataset

# %%
import seaborn as sns
from matplotlib import rcParams

sns.set(font="NanumGothic", 
        rc={"axes.unicode_minus":False, 'figure.figsize':(12,4)},
        style='darkgrid')

sns.countplot(y=dataset['train']['category'])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
sns.countplot(y=dataset['train']['media_sub_type'])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
rcParams["figure.figsize"] = (12,8) 
sns.countplot(y=dataset['train']['media_name'])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
rcParams["figure.figsize"] = (12,4) 
sns.displot(dataset['train']['char_count'], height = 4, aspect = 3)

# %%
article_len =  [len(e) for e in dataset['train']['article']]
sns.displot(article_len, height=4, aspect=3)

# %%
extractive_len =  [len(e) for e in dataset['train']['extractive'] if e!=None]
sns.displot(extractive_len, height=4, aspect=3)

# %%
abstractive_len =  [len(e) for e in dataset['train']['abstractive'] if e!=None]
sns.displot(abstractive_len, height=4, aspect=3)

# %%
sns.boxplot(data=[article_len, extractive_len, abstractive_len])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2.1. valid dataset

# %%
import seaborn as sns
from matplotlib import rcParams

sns.set(font="NanumGothic", 
        rc={"axes.unicode_minus":False, 'figure.figsize':(12,4)},
        style='darkgrid')

sns.countplot(y=dataset['valid']['category'])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
sns.countplot(y=dataset['valid']['media_sub_type'])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
rcParams["figure.figsize"] = (12,8) 
sns.countplot(y=dataset['valid']['media_name'])
# Out:
# <AxesSubplot:xlabel='count'>

# %%
rcParams["figure.figsize"] = (12,4) 
sns.displot(dataset['valid']['char_count'], height = 4, aspect = 3)

# %%
article_len =  [len(e) for e in dataset['valid']['article']]
sns.displot(article_len, height=4, aspect=3)

# %%
extractive_len =  [len(e) for e in dataset['valid']['extractive'] if e!=None]
sns.displot(extractive_len, height=4, aspect=3)

# %%
abstractive_len =  [len(e) for e in dataset['valid']['abstractive'] if e!=None]
sns.displot(abstractive_len, height=4, aspect=3)

# %%
sns.boxplot(data=[article_len, extractive_len, abstractive_len])
# Out:
# <AxesSubplot:>
